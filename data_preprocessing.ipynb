# %%
## importing libararies
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

## libraries for preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
## load data
df = pd.read_csv("artifacts/train_data.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D             master's degree      standard
# 1  female        group C           bachelor's degree  free/reduced
# 2  female        group D                some college  free/reduced
# 3    male        group C             master's degree  free/reduced
# 4    male        group E                 high school      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          62             70             75
# 1               completed          66             83             83
# 2                    none          79             89             86
# 3                    none          61             67             66
# 4                    none          73             64             57

# %%
df["overall_score"] = df["math score"] + df["reading score"] + df["writing score"]

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D             master's degree      standard
# 1  female        group C           bachelor's degree  free/reduced
# 2  female        group D                some college  free/reduced
# 3    male        group C             master's degree  free/reduced
# 4    male        group E                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          62             70             75
# 1               completed          66             83             83
# 2                    none          79             89             86
# 3                    none          61             67             66
# 4                    none          73             64             57
#
#    overall_score
# 0            207
# 1            232
# 2            254
# 3            194
# 4            194

# %%
df.gender.value_counts()
# Out:
# gender
# female    421
# male      379
# Name: count, dtype: int64

# %%
df["race/ethnicity"].value_counts()
# Out:
# race/ethnicity
# group C    260
# group D    202
# group B    153
# group E    116
# group A     69
# Name: count, dtype: int64

# %%
## one hot encoding helps to encode nominal categorical variables into numerical variables. It creates new columns for each category and assigns a value of 1 or 0 to indicate the presence or absence of that category in the original data.
cat_one = ["gender", "lunch", "test preparation course"]
ohe = OneHotEncoder( drop="first")
for i in cat_one:
    df[i] = ohe.fit_transform(df[[i]]).toarray()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education  lunch  \
# 0     0.0        group D             master's degree    1.0
# 1     0.0        group C           bachelor's degree    0.0
# 2     0.0        group D                some college    0.0
# 3     1.0        group C             master's degree    0.0
# 4     1.0        group E                 high school    1.0
#
#    test preparation course  math score  reading score  writing score  \
# 0                      1.0          62             70             75
# 1                      0.0          66             83             83
# 2                      1.0          79             89             86
# 3                      1.0          61             67             66
# 4                      1.0          73             64             57
#
#    overall_score
# 0            207
# 1            232
# 2            254
# 3            194
# 4            194

# %%
## label encoding helps to encode ordinal categorical variables into numerical variables. It assigns a unique integer to each category based on the order of the categories in the original data.
cat_label = ["race/ethnicity", "parental level of education"]
enco = LabelEncoder()
for i in cat_label:
    df[i] = enco.fit_transform(df[i])

# %%
df.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0     0.0               3                            3    1.0
# 1     0.0               2                            1    0.0
# 2     0.0               3                            4    0.0
# 3     1.0               2                            3    0.0
# 4     1.0               4                            2    1.0
#
#    test preparation course  math score  reading score  writing score  \
# 0                      1.0          62             70             75
# 1                      0.0          66             83             83
# 2                      1.0          79             89             86
# 3                      1.0          61             67             66
# 4                      1.0          73             64             57
#
#    overall_score
# 0            207
# 1            232
# 2            254
# 3            194
# 4            194

# %%
## separating target and features
x = df.drop(columns=["overall_score"])
y = df["overall_score"]

# %%
## Normalization
normal = MinMaxScaler()
x = normal.fit_transform(x)

# %%
## train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
## model building
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
model = LinearRegression()
model.fit(x_train, y_train)
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)
print("R2 score for train data: ", r2_score(y_train, y_pred_train))
print("R2 score for test data: ", r2_score(y_test, y_pred_test))
print("Mean squared error for train data: ", mean_squared_error(y_train, y_pred_train))
print("Mean squared error for test data: ", mean_squared_error(y_test, y_pred_test))
# Out:
# R2 score for train data:  1.0
# R2 score for test data:  1.0
# Mean squared error for train data:  5.4292562940930914e-27
# Mean squared error for test data:  5.918350055330119e-27

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)
print("R2 score for train data: ", r2_score(y_train, y_pred_train))
print("R2 score for test data: ", r2_score(y_test, y_pred_test))
print("Mean squared error for train data: ", mean_squared_error(y_train, y_pred_train))
print("Mean squared error for test data: ", mean_squared_error(y_test, y_pred_test))
# Out:
# R2 score for train data:  1.0
# R2 score for test data:  0.9894207408387286
# Mean squared error for train data:  0.0
# Mean squared error for test data:  19.3125

# %%
plot_tree(model, feature_names=df.drop(columns=["overall_score"]).columns, filled=True)
plt.show()
# Out:
# [Text(0.469656430984556, 0.9642857142857143, 'reading score <= 0.572\nsquared_error = 1784.477\nsamples = 640\nvalue = 203.739'),
#  Text(0.1766891891891892, 0.8928571428571429, 'writing score <= 0.429\nsquared_error = 747.723\nsamples = 292\nvalue = 167.798'),
#  Text(0.3231728100868726, 0.9285714285714286, 'True  '),
#  Text(0.05649131274131274, 0.8214285714285714, 'writing score <= 0.3\nsquared_error = 534.096\nsamples = 89\nvalue = 137.247'),
#  Text(0.014864864864864866, 0.75, 'writing score <= 0.218\nsquared_error = 370.514\nsamples = 22\nvalue = 105.591'),
#  Text(0.006177606177606178, 0.6785714285714286, 'reading score <= 0.033\nsquared_error = 194.917\nsamples = 6\nvalue = 79.5'),
#  Text(0.003088803088803089, 0.6071428571428571, 'writing score <= 0.047\nsquared_error = 49.0\nsamples = 2\nvalue = 62.0'),
#  Text(0.0015444015444015444, 0.5357142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.004633204633204633, 0.5357142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.009266409266409266, 0.6071428571428571, 'math score <= 0.13\nsquared_error = 38.188\nsamples = 4\nvalue = 88.25'),
#  Text(0.007722007722007722, 0.5357142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 78.0'),
#  Text(0.010810810810810811, 0.5357142857142857, 'parental level of education <= 0.9\nsquared_error = 4.222\nsamples = 3\nvalue = 91.667'),
#  Text(0.009266409266409266, 0.4642857142857143, 'parental level of education <= 0.6\nsquared_error = 1.0\nsamples = 2\nvalue = 93.0'),
#  Text(0.007722007722007722, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 92.0'),
#  Text(0.010810810810810811, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 94.0'),
#  Text(0.012355212355212355, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 89.0'),
#  Text(0.023552123552123553, 0.6785714285714286, 'math score <= 0.272\nsquared_error = 85.359\nsamples = 16\nvalue = 115.375'),
#  Text(0.018532818532818532, 0.6071428571428571, 'math score <= 0.234\nsquared_error = 14.889\nsamples = 3\nvalue = 98.667'),
#  Text(0.01698841698841699, 0.5357142857142857, 'gender <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 96.0'),
#  Text(0.015444015444015444, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 95.0'),
#  Text(0.018532818532818532, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.020077220077220077, 0.5357142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.02857142857142857, 0.6071428571428571, 'writing score <= 0.253\nsquared_error = 22.331\nsamples = 13\nvalue = 119.231'),
#  Text(0.023166023166023165, 0.5357142857142857, 'parental level of education <= 0.2\nsquared_error = 5.36\nsamples = 5\nvalue = 115.2'),
#  Text(0.021621621621621623, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 119.0'),
#  Text(0.02471042471042471, 0.4642857142857143, 'parental level of education <= 0.9\nsquared_error = 2.188\nsamples = 4\nvalue = 114.25'),
#  Text(0.023166023166023165, 0.39285714285714285, 'math score <= 0.364\nsquared_error = 0.667\nsamples = 3\nvalue = 115.0'),
#  Text(0.021621621621621623, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 114.0'),
#  Text(0.02471042471042471, 0.32142857142857145, 'reading score <= 0.164\nsquared_error = 0.25\nsamples = 2\nvalue = 115.5'),
#  Text(0.023166023166023165, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 116.0'),
#  Text(0.026254826254826256, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 115.0'),
#  Text(0.026254826254826256, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 112.0'),
#  Text(0.03397683397683398, 0.5357142857142857, 'math score <= 0.353\nsquared_error = 16.438\nsamples = 8\nvalue = 121.75'),
#  Text(0.03088803088803089, 0.4642857142857143, 'math score <= 0.299\nsquared_error = 5.36\nsamples = 5\nvalue = 119.2'),
#  Text(0.029343629343629343, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 115.0'),
#  Text(0.032432432432432434, 0.39285714285714285, 'writing score <= 0.276\nsquared_error = 1.188\nsamples = 4\nvalue = 120.25'),
#  Text(0.03088803088803089, 0.32142857142857145, 'test preparation course <= 0.5\nsquared_error = 0.222\nsamples = 3\nvalue = 119.667'),
#  Text(0.029343629343629343, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 119.0'),
#  Text(0.032432432432432434, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 120.0'),
#  Text(0.03397683397683398, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 122.0'),
#  Text(0.037065637065637064, 0.4642857142857143, 'parental level of education <= 0.2\nsquared_error = 6.0\nsamples = 3\nvalue = 126.0'),
#  Text(0.03552123552123552, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 123.0'),
#  Text(0.03861003861003861, 0.39285714285714285, 'lunch <= 0.5\nsquared_error = 2.25\nsamples = 2\nvalue = 127.5'),
#  Text(0.037065637065637064, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 126.0'),
#  Text(0.040154440154440155, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 129.0'),
#  Text(0.09811776061776062, 0.75, 'math score <= 0.467\nsquared_error = 150.708\nsamples = 67\nvalue = 147.642'),
#  Text(0.0692084942084942, 0.6785714285714286, 'reading score <= 0.303\nsquared_error = 80.198\nsamples = 33\nvalue = 139.273'),
#  Text(0.057335907335907335, 0.6071428571428571, 'parental level of education <= 0.7\nsquared_error = 57.884\nsamples = 11\nvalue = 130.545'),
#  Text(0.05289575289575289, 0.5357142857142857, 'writing score <= 0.376\nsquared_error = 9.984\nsamples = 8\nvalue = 134.625'),
#  Text(0.04864864864864865, 0.4642857142857143, 'race/ethnicity <= 0.375\nsquared_error = 4.472\nsamples = 6\nvalue = 133.167'),
#  Text(0.044787644787644784, 0.39285714285714285, 'reading score <= 0.27\nsquared_error = 0.25\nsamples = 2\nvalue = 135.5'),
#  Text(0.043243243243243246, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 136.0'),
#  Text(0.04633204633204633, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 135.0'),
#  Text(0.05250965250965251, 0.39285714285714285, 'writing score <= 0.329\nsquared_error = 2.5\nsamples = 4\nvalue = 132.0'),
#  Text(0.04942084942084942, 0.32142857142857145, 'race/ethnicity <= 0.75\nsquared_error = 0.25\nsamples = 2\nvalue = 130.5'),
#  Text(0.047876447876447875, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 131.0'),
#  Text(0.050965250965250966, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 130.0'),
#  Text(0.055598455598455596, 0.32142857142857145, 'parental level of education <= 0.3\nsquared_error = 0.25\nsamples = 2\nvalue = 133.5'),
#  Text(0.05405405405405406, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 133.0'),
#  Text(0.05714285714285714, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 134.0'),
#  Text(0.05714285714285714, 0.4642857142857143, 'race/ethnicity <= 0.625\nsquared_error = 1.0\nsamples = 2\nvalue = 139.0'),
#  Text(0.055598455598455596, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 138.0'),
#  Text(0.05868725868725869, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.06177606177606178, 0.5357142857142857, 'reading score <= 0.23\nsquared_error = 22.889\nsamples = 3\nvalue = 119.667'),
#  Text(0.06023166023166023, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 113.0'),
#  Text(0.06332046332046332, 0.4642857142857143, 'parental level of education <= 0.9\nsquared_error = 1.0\nsamples = 2\nvalue = 123.0'),
#  Text(0.06177606177606178, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 122.0'),
#  Text(0.06486486486486487, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 124.0'),
#  Text(0.08108108108108109, 0.6071428571428571, 'math score <= 0.353\nsquared_error = 34.231\nsamples = 22\nvalue = 143.636'),
#  Text(0.07335907335907337, 0.5357142857142857, 'reading score <= 0.447\nsquared_error = 23.633\nsamples = 7\nvalue = 137.714'),
#  Text(0.07181467181467181, 0.4642857142857143, 'writing score <= 0.371\nsquared_error = 7.0\nsamples = 6\nvalue = 136.0'),
#  Text(0.06795366795366796, 0.39285714285714285, 'math score <= 0.332\nsquared_error = 3.25\nsamples = 4\nvalue = 134.5'),
#  Text(0.06486486486486487, 0.32142857142857145, 'reading score <= 0.355\nsquared_error = 1.0\nsamples = 2\nvalue = 133.0'),
#  Text(0.06332046332046332, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 132.0'),
#  Text(0.06640926640926641, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 134.0'),
#  Text(0.07104247104247104, 0.32142857142857145, 'gender <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 136.0'),
#  Text(0.0694980694980695, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 137.0'),
#  Text(0.07258687258687259, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 135.0'),
#  Text(0.07567567567567568, 0.39285714285714285, 'race/ethnicity <= 0.375\nsquared_error = 1.0\nsamples = 2\nvalue = 139.0'),
#  Text(0.07413127413127413, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 138.0'),
#  Text(0.07722007722007722, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.0749034749034749, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 148.0'),
#  Text(0.0888030888030888, 0.5357142857142857, 'reading score <= 0.421\nsquared_error = 15.173\nsamples = 15\nvalue = 146.4'),
#  Text(0.08494208494208494, 0.4642857142857143, 'writing score <= 0.341\nsquared_error = 6.5\nsamples = 12\nvalue = 145.0'),
#  Text(0.08185328185328185, 0.39285714285714285, 'writing score <= 0.324\nsquared_error = 2.25\nsamples = 2\nvalue = 141.5'),
#  Text(0.08030888030888031, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.0833976833976834, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 143.0'),
#  Text(0.08803088803088803, 0.39285714285714285, 'parental level of education <= 0.1\nsquared_error = 4.41\nsamples = 10\nvalue = 145.7'),
#  Text(0.08648648648648649, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 151.0'),
#  Text(0.08957528957528957, 0.32142857142857145, 'gender <= 0.5\nsquared_error = 1.432\nsamples = 9\nvalue = 145.111'),
#  Text(0.08494208494208494, 0.25, 'math score <= 0.364\nsquared_error = 1.0\nsamples = 4\nvalue = 146.0'),
#  Text(0.0833976833976834, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 147.0'),
#  Text(0.08648648648648649, 0.17857142857142858, 'writing score <= 0.4\nsquared_error = 0.889\nsamples = 3\nvalue = 145.667'),
#  Text(0.08494208494208494, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 147.0'),
#  Text(0.08803088803088803, 0.10714285714285714, 'squared_error = 0.0\nsamples = 2\nvalue = 145.0'),
#  Text(0.09420849420849421, 0.25, 'math score <= 0.408\nsquared_error = 0.64\nsamples = 5\nvalue = 144.4'),
#  Text(0.09266409266409266, 0.17857142857142858, 'writing score <= 0.406\nsquared_error = 0.25\nsamples = 2\nvalue = 143.5'),
#  Text(0.09111969111969112, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 143.0'),
#  Text(0.09420849420849421, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 144.0'),
#  Text(0.09575289575289575, 0.17857142857142858, 'squared_error = 0.0\nsamples = 3\nvalue = 145.0'),
#  Text(0.09266409266409266, 0.4642857142857143, 'writing score <= 0.353\nsquared_error = 10.667\nsamples = 3\nvalue = 152.0'),
#  Text(0.09111969111969112, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 148.0'),
#  Text(0.09420849420849421, 0.39285714285714285, 'race/ethnicity <= 0.375\nsquared_error = 4.0\nsamples = 2\nvalue = 154.0'),
#  Text(0.09266409266409266, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 156.0'),
#  Text(0.09575289575289575, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(0.12702702702702703, 0.6785714285714286, 'math score <= 0.603\nsquared_error = 85.18\nsamples = 34\nvalue = 155.765'),
#  Text(0.11274131274131274, 0.6071428571428571, 'reading score <= 0.309\nsquared_error = 42.222\nsamples = 30\nvalue = 153.333'),
#  Text(0.10193050193050193, 0.5357142857142857, 'writing score <= 0.335\nsquared_error = 17.583\nsamples = 6\nvalue = 143.5'),
#  Text(0.09884169884169884, 0.4642857142857143, 'math score <= 0.5\nsquared_error = 4.5\nsamples = 4\nvalue = 141.0'),
#  Text(0.0972972972972973, 0.39285714285714285, 'squared_error = 0.0\nsamples = 2\nvalue = 139.0'),
#  Text(0.10038610038610038, 0.39285714285714285, 'race/ethnicity <= 0.25\nsquared_error = 1.0\nsamples = 2\nvalue = 143.0'),
#  Text(0.09884169884169884, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 144.0'),
#  Text(0.10193050193050193, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.10501930501930502, 0.4642857142857143, 'writing score <= 0.359\nsquared_error = 6.25\nsamples = 2\nvalue = 148.5'),
#  Text(0.10347490347490347, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 146.0'),
#  Text(0.10656370656370656, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 151.0'),
#  Text(0.12355212355212356, 0.5357142857142857, 'reading score <= 0.362\nsquared_error = 18.165\nsamples = 24\nvalue = 155.792'),
#  Text(0.11351351351351352, 0.4642857142857143, 'math score <= 0.484\nsquared_error = 12.234\nsamples = 8\nvalue = 152.375'),
#  Text(0.10965250965250965, 0.39285714285714285, 'test preparation course <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 148.0'),
#  Text(0.10810810810810811, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 147.0'),
#  Text(0.11119691119691119, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 149.0'),
#  Text(0.11737451737451737, 0.39285714285714285, 'parental level of education <= 0.6\nsquared_error = 7.472\nsamples = 6\nvalue = 153.833'),
#  Text(0.11428571428571428, 0.32142857142857145, 'math score <= 0.587\nsquared_error = 2.0\nsamples = 3\nvalue = 156.0'),
#  Text(0.11274131274131274, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 155.0'),
#  Text(0.11583011583011583, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 158.0'),
#  Text(0.12046332046332046, 0.32142857142857145, 'writing score <= 0.324\nsquared_error = 3.556\nsamples = 3\nvalue = 151.667'),
#  Text(0.11891891891891893, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 149.0'),
#  Text(0.122007722007722, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 153.0'),
#  Text(0.1335907335907336, 0.4642857142857143, 'math score <= 0.527\nsquared_error = 12.375\nsamples = 16\nvalue = 157.5'),
#  Text(0.1305019305019305, 0.39285714285714285, 'reading score <= 0.454\nsquared_error = 6.639\nsamples = 12\nvalue = 156.167'),
#  Text(0.12895752895752896, 0.32142857142857145, 'writing score <= 0.406\nsquared_error = 2.612\nsamples = 11\nvalue = 155.545'),
#  Text(0.1250965250965251, 0.25, 'reading score <= 0.401\nsquared_error = 1.333\nsamples = 9\nvalue = 155.0'),
#  Text(0.122007722007722, 0.17857142857142858, 'writing score <= 0.365\nsquared_error = 0.56\nsamples = 5\nvalue = 154.2'),
#  Text(0.12046332046332046, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 153.0'),
#  Text(0.12355212355212356, 0.10714285714285714, 'reading score <= 0.388\nsquared_error = 0.25\nsamples = 4\nvalue = 154.5'),
#  Text(0.122007722007722, 0.03571428571428571, 'squared_error = 0.0\nsamples = 2\nvalue = 154.0'),
#  Text(0.1250965250965251, 0.03571428571428571, 'squared_error = 0.0\nsamples = 2\nvalue = 155.0'),
#  Text(0.12818532818532818, 0.17857142857142858, 'race/ethnicity <= 0.125\nsquared_error = 0.5\nsamples = 4\nvalue = 156.0'),
#  Text(0.12664092664092663, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 155.0'),
#  Text(0.12972972972972974, 0.10714285714285714, 'writing score <= 0.382\nsquared_error = 0.222\nsamples = 3\nvalue = 156.333'),
#  Text(0.12818532818532818, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 157.0'),
#  Text(0.13127413127413126, 0.03571428571428571, 'squared_error = 0.0\nsamples = 2\nvalue = 156.0'),
#  Text(0.13281853281853281, 0.25, 'parental level of education <= 0.4\nsquared_error = 1.0\nsamples = 2\nvalue = 158.0'),
#  Text(0.13127413127413126, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 159.0'),
#  Text(0.13436293436293437, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 157.0'),
#  Text(0.13204633204633204, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 163.0'),
#  Text(0.13667953667953667, 0.39285714285714285, 'reading score <= 0.382\nsquared_error = 8.25\nsamples = 4\nvalue = 161.5'),
#  Text(0.13513513513513514, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 157.0'),
#  Text(0.13822393822393822, 0.32142857142857145, 'math score <= 0.549\nsquared_error = 2.0\nsamples = 3\nvalue = 163.0'),
#  Text(0.13667953667953667, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 161.0'),
#  Text(0.13976833976833977, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 164.0'),
#  Text(0.14131274131274132, 0.6071428571428571, 'math score <= 0.652\nsquared_error = 30.5\nsamples = 4\nvalue = 174.0'),
#  Text(0.13976833976833977, 0.5357142857142857, 'reading score <= 0.421\nsquared_error = 4.667\nsamples = 3\nvalue = 171.0'),
#  Text(0.13822393822393822, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.14131274131274132, 0.4642857142857143, 'math score <= 0.614\nsquared_error = 0.25\nsamples = 2\nvalue = 172.5'),
#  Text(0.13976833976833977, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.14285714285714285, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.14285714285714285, 0.5357142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 183.0'),
#  Text(0.29688706563706563, 0.8214285714285714, 'math score <= 0.549\nsquared_error = 252.776\nsamples = 203\nvalue = 181.192'),
#  Text(0.22598938223938225, 0.75, 'writing score <= 0.535\nsquared_error = 127.107\nsamples = 91\nvalue = 168.945'),
#  Text(0.18445945945945946, 0.6785714285714286, 'reading score <= 0.428\nsquared_error = 48.929\nsamples = 56\nvalue = 162.0'),
#  Text(0.1640926640926641, 0.6071428571428571, 'math score <= 0.467\nsquared_error = 28.942\nsamples = 26\nvalue = 157.5'),
#  Text(0.1552123552123552, 0.5357142857142857, 'parental level of education <= 0.7\nsquared_error = 12.965\nsamples = 16\nvalue = 154.312'),
#  Text(0.14903474903474903, 0.4642857142857143, 'writing score <= 0.465\nsquared_error = 4.938\nsamples = 8\nvalue = 157.25'),
#  Text(0.14594594594594595, 0.39285714285714285, 'race/ethnicity <= 0.375\nsquared_error = 0.222\nsamples = 3\nvalue = 154.667'),
#  Text(0.1444015444015444, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 154.0'),
#  Text(0.14749034749034748, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 155.0'),
#  Text(0.15212355212355214, 0.39285714285714285, 'parental level of education <= 0.5\nsquared_error = 1.36\nsamples = 5\nvalue = 158.8'),
#  Text(0.15057915057915058, 0.32142857142857145, 'reading score <= 0.408\nsquared_error = 0.188\nsamples = 4\nvalue = 158.25'),
#  Text(0.14903474903474903, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 158.0'),
#  Text(0.15212355212355214, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 159.0'),
#  Text(0.15366795366795366, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 161.0'),
#  Text(0.1613899613899614, 0.4642857142857143, 'math score <= 0.408\nsquared_error = 3.734\nsamples = 8\nvalue = 151.375'),
#  Text(0.1583011583011583, 0.39285714285714285, 'parental level of education <= 0.9\nsquared_error = 0.56\nsamples = 5\nvalue = 150.2'),
#  Text(0.15675675675675677, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 151.0'),
#  Text(0.15984555984555984, 0.32142857142857145, 'test preparation course <= 0.5\nsquared_error = 0.222\nsamples = 3\nvalue = 149.667'),
#  Text(0.1583011583011583, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 150.0'),
#  Text(0.1613899613899614, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 149.0'),
#  Text(0.16447876447876447, 0.39285714285714285, 'test preparation course <= 0.5\nsquared_error = 2.889\nsamples = 3\nvalue = 153.333'),
#  Text(0.16293436293436295, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 151.0'),
#  Text(0.16602316602316602, 0.32142857142857145, 'race/ethnicity <= 0.625\nsquared_error = 0.25\nsamples = 2\nvalue = 154.5'),
#  Text(0.16447876447876447, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 154.0'),
#  Text(0.16756756756756758, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 155.0'),
#  Text(0.17297297297297298, 0.5357142857142857, 'reading score <= 0.329\nsquared_error = 12.24\nsamples = 10\nvalue = 162.6'),
#  Text(0.17142857142857143, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 154.0'),
#  Text(0.1745173745173745, 0.4642857142857143, 'reading score <= 0.362\nsquared_error = 4.469\nsamples = 9\nvalue = 163.556'),
#  Text(0.17065637065637065, 0.39285714285714285, 'race/ethnicity <= 0.25\nsquared_error = 0.889\nsamples = 3\nvalue = 161.667'),
#  Text(0.1691119691119691, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 163.0'),
#  Text(0.1722007722007722, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 161.0'),
#  Text(0.1783783783783784, 0.39285714285714285, 'test preparation course <= 0.5\nsquared_error = 3.583\nsamples = 6\nvalue = 164.5'),
#  Text(0.17528957528957528, 0.32142857142857145, 'reading score <= 0.382\nsquared_error = 2.0\nsamples = 3\nvalue = 166.0'),
#  Text(0.17374517374517376, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 164.0'),
#  Text(0.17683397683397684, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 167.0'),
#  Text(0.18146718146718147, 0.32142857142857145, 'writing score <= 0.453\nsquared_error = 0.667\nsamples = 3\nvalue = 163.0'),
#  Text(0.1799227799227799, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(0.18301158301158302, 0.25, 'parental level of education <= 0.2\nsquared_error = 0.25\nsamples = 2\nvalue = 163.5'),
#  Text(0.18146718146718147, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 164.0'),
#  Text(0.18455598455598454, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 163.0'),
#  Text(0.20482625482625483, 0.6071428571428571, 'math score <= 0.44\nsquared_error = 33.49\nsamples = 30\nvalue = 165.9'),
#  Text(0.18996138996138995, 0.5357142857142857, 'writing score <= 0.476\nsquared_error = 27.2\nsamples = 10\nvalue = 160.0'),
#  Text(0.18455598455598454, 0.4642857142857143, 'writing score <= 0.447\nsquared_error = 11.556\nsamples = 3\nvalue = 153.333'),
#  Text(0.18301158301158302, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 158.0'),
#  Text(0.1861003861003861, 0.39285714285714285, 'parental level of education <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 151.0'),
#  Text(0.18455598455598454, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 150.0'),
#  Text(0.18764478764478765, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(0.19536679536679535, 0.4642857142857143, 'parental level of education <= 0.2\nsquared_error = 6.694\nsamples = 7\nvalue = 162.857'),
#  Text(0.19227799227799228, 0.39285714285714285, 'reading score <= 0.507\nsquared_error = 0.188\nsamples = 4\nvalue = 160.75'),
#  Text(0.19073359073359072, 0.32142857142857145, 'squared_error = 0.0\nsamples = 3\nvalue = 161.0'),
#  Text(0.19382239382239383, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 160.0'),
#  Text(0.19845559845559846, 0.39285714285714285, 'math score <= 0.38\nsquared_error = 1.556\nsamples = 3\nvalue = 165.667'),
#  Text(0.1969111969111969, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 164.0'),
#  Text(0.2, 0.32142857142857145, 'lunch <= 0.5\nsquared_error = 0.25\nsamples = 2\nvalue = 166.5'),
#  Text(0.19845559845559846, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(0.20154440154440154, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 167.0'),
#  Text(0.21969111969111968, 0.5357142857142857, 'reading score <= 0.454\nsquared_error = 10.528\nsamples = 20\nvalue = 168.85'),
#  Text(0.2084942084942085, 0.4642857142857143, 'math score <= 0.473\nsquared_error = 9.0\nsamples = 8\nvalue = 166.5'),
#  Text(0.20463320463320464, 0.39285714285714285, 'writing score <= 0.465\nsquared_error = 0.25\nsamples = 2\nvalue = 162.5'),
#  Text(0.2030888030888031, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 163.0'),
#  Text(0.20617760617760617, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(0.21235521235521235, 0.39285714285714285, 'race/ethnicity <= 0.875\nsquared_error = 4.806\nsamples = 6\nvalue = 167.833'),
#  Text(0.20926640926640927, 0.32142857142857145, 'race/ethnicity <= 0.625\nsquared_error = 1.688\nsamples = 4\nvalue = 166.75'),
#  Text(0.20772200772200772, 0.25, 'gender <= 0.5\nsquared_error = 0.889\nsamples = 3\nvalue = 167.333'),
#  Text(0.20617760617760617, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.20926640926640927, 0.17857142857142858, 'test preparation course <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 167.0'),
#  Text(0.20772200772200772, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.21081081081081082, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(0.21081081081081082, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 165.0'),
#  Text(0.21544401544401545, 0.32142857142857145, 'math score <= 0.511\nsquared_error = 4.0\nsamples = 2\nvalue = 170.0'),
#  Text(0.2138996138996139, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.21698841698841698, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.2308880308880309, 0.4642857142857143, 'math score <= 0.495\nsquared_error = 5.41\nsamples = 12\nvalue = 170.417'),
#  Text(0.2247104247104247, 0.39285714285714285, 'parental level of education <= 0.1\nsquared_error = 3.234\nsamples = 8\nvalue = 169.375'),
#  Text(0.22162162162162163, 0.32142857142857145, 'writing score <= 0.465\nsquared_error = 0.25\nsamples = 2\nvalue = 167.5'),
#  Text(0.22007722007722008, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.22316602316602316, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 167.0'),
#  Text(0.2277992277992278, 0.32142857142857145, 'race/ethnicity <= 0.625\nsquared_error = 2.667\nsamples = 6\nvalue = 170.0'),
#  Text(0.22625482625482626, 0.25, 'math score <= 0.473\nsquared_error = 1.04\nsamples = 5\nvalue = 169.4'),
#  Text(0.2247104247104247, 0.17857142857142858, 'lunch <= 0.5\nsquared_error = 0.5\nsamples = 4\nvalue = 169.0'),
#  Text(0.22316602316602316, 0.10714285714285714, 'test preparation course <= 0.5\nsquared_error = 0.222\nsamples = 3\nvalue = 169.333'),
#  Text(0.22162162162162163, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(0.2247104247104247, 0.03571428571428571, 'squared_error = 0.0\nsamples = 2\nvalue = 169.0'),
#  Text(0.22625482625482626, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.2277992277992278, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 171.0'),
#  Text(0.22934362934362934, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.23706563706563707, 0.39285714285714285, 'writing score <= 0.482\nsquared_error = 3.25\nsamples = 4\nvalue = 172.5'),
#  Text(0.23397683397683397, 0.32142857142857145, 'math score <= 0.522\nsquared_error = 1.0\nsamples = 2\nvalue = 171.0'),
#  Text(0.23243243243243245, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(0.23552123552123552, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.24015444015444015, 0.32142857142857145, 'gender <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 174.0'),
#  Text(0.2386100386100386, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.2416988416988417, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(0.26751930501930504, 0.6785714285714286, 'writing score <= 0.641\nsquared_error = 51.54\nsamples = 35\nvalue = 180.057'),
#  Text(0.2551158301158301, 0.6071428571428571, 'math score <= 0.44\nsquared_error = 26.929\nsamples = 30\nvalue = 177.933'),
#  Text(0.24478764478764478, 0.5357142857142857, 'writing score <= 0.588\nsquared_error = 14.857\nsamples = 7\nvalue = 172.0'),
#  Text(0.2416988416988417, 0.4642857142857143, 'reading score <= 0.507\nsquared_error = 2.0\nsamples = 3\nvalue = 168.0'),
#  Text(0.24015444015444015, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(0.24324324324324326, 0.39285714285714285, 'squared_error = 0.0\nsamples = 2\nvalue = 169.0'),
#  Text(0.2478764478764479, 0.4642857142857143, 'race/ethnicity <= 0.625\nsquared_error = 3.5\nsamples = 4\nvalue = 175.0'),
#  Text(0.24633204633204633, 0.39285714285714285, 'parental level of education <= 0.5\nsquared_error = 0.667\nsamples = 3\nvalue = 176.0'),
#  Text(0.24478764478764478, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(0.2478764478764479, 0.32142857142857145, 'writing score <= 0.618\nsquared_error = 0.25\nsamples = 2\nvalue = 176.5'),
#  Text(0.24633204633204633, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 176.0'),
#  Text(0.2494208494208494, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(0.2494208494208494, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.26544401544401547, 0.5357142857142857, 'reading score <= 0.5\nsquared_error = 16.628\nsamples = 23\nvalue = 179.739'),
#  Text(0.25868725868725867, 0.4642857142857143, 'writing score <= 0.559\nsquared_error = 8.29\nsamples = 10\nvalue = 176.9'),
#  Text(0.2555984555984556, 0.39285714285714285, 'reading score <= 0.474\nsquared_error = 1.688\nsamples = 4\nvalue = 174.25'),
#  Text(0.25405405405405407, 0.32142857142857145, 'parental level of education <= 0.2\nsquared_error = 0.889\nsamples = 3\nvalue = 173.667'),
#  Text(0.2525096525096525, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 173.0'),
#  Text(0.2555984555984556, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(0.2571428571428571, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 176.0'),
#  Text(0.2617760617760618, 0.39285714285714285, 'math score <= 0.538\nsquared_error = 4.889\nsamples = 6\nvalue = 178.667'),
#  Text(0.2602316602316602, 0.32142857142857145, 'parental level of education <= 0.5\nsquared_error = 1.36\nsamples = 5\nvalue = 177.8'),
#  Text(0.25868725868725867, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 179.0'),
#  Text(0.2617760617760618, 0.25, 'math score <= 0.489\nsquared_error = 0.667\nsamples = 3\nvalue = 177.0'),
#  Text(0.2602316602316602, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 176.0'),
#  Text(0.2633204633204633, 0.17857142857142858, 'parental level of education <= 0.7\nsquared_error = 0.25\nsamples = 2\nvalue = 177.5'),
#  Text(0.2617760617760618, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(0.2648648648648649, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.2633204633204633, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 183.0'),
#  Text(0.2722007722007722, 0.4642857142857143, 'math score <= 0.473\nsquared_error = 12.071\nsamples = 13\nvalue = 181.923'),
#  Text(0.26795366795366793, 0.39285714285714285, 'reading score <= 0.52\nsquared_error = 3.76\nsamples = 5\nvalue = 178.8'),
#  Text(0.26640926640926643, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(0.2694980694980695, 0.32142857142857145, 'math score <= 0.462\nsquared_error = 0.188\nsamples = 4\nvalue = 179.75'),
#  Text(0.26795366795366793, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 180.0'),
#  Text(0.27104247104247103, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 179.0'),
#  Text(0.27644787644787644, 0.39285714285714285, 'writing score <= 0.547\nsquared_error = 7.359\nsamples = 8\nvalue = 183.875'),
#  Text(0.2749034749034749, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.277992277992278, 0.32142857142857145, 'math score <= 0.527\nsquared_error = 2.776\nsamples = 7\nvalue = 184.714'),
#  Text(0.27413127413127414, 0.25, 'writing score <= 0.6\nsquared_error = 2.0\nsamples = 5\nvalue = 184.0'),
#  Text(0.27104247104247103, 0.17857142857142858, 'lunch <= 0.5\nsquared_error = 0.667\nsamples = 3\nvalue = 183.0'),
#  Text(0.2694980694980695, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 184.0'),
#  Text(0.2725868725868726, 0.10714285714285714, 'race/ethnicity <= 0.25\nsquared_error = 0.25\nsamples = 2\nvalue = 182.5'),
#  Text(0.27104247104247103, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.27413127413127414, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 183.0'),
#  Text(0.27722007722007724, 0.17857142857142858, 'reading score <= 0.533\nsquared_error = 0.25\nsamples = 2\nvalue = 185.5'),
#  Text(0.2756756756756757, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.27876447876447874, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 186.0'),
#  Text(0.28185328185328185, 0.25, 'lunch <= 0.5\nsquared_error = 0.25\nsamples = 2\nvalue = 186.5'),
#  Text(0.2803088803088803, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 187.0'),
#  Text(0.2833976833976834, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 186.0'),
#  Text(0.2799227799227799, 0.6071428571428571, 'math score <= 0.522\nsquared_error = 9.76\nsamples = 5\nvalue = 192.8'),
#  Text(0.2768339768339768, 0.5357142857142857, 'test preparation course <= 0.5\nsquared_error = 0.889\nsamples = 3\nvalue = 190.333'),
#  Text(0.2752895752895753, 0.4642857142857143, 'squared_error = 0.0\nsamples = 2\nvalue = 191.0'),
#  Text(0.27837837837837837, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 189.0'),
#  Text(0.283011583011583, 0.5357142857142857, 'parental level of education <= 0.9\nsquared_error = 0.25\nsamples = 2\nvalue = 196.5'),
#  Text(0.28146718146718147, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 197.0'),
#  Text(0.2845559845559846, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 196.0'),
#  Text(0.36778474903474906, 0.75, 'reading score <= 0.493\nsquared_error = 133.997\nsamples = 112\nvalue = 191.143'),
#  Text(0.325965250965251, 0.6785714285714286, 'writing score <= 0.535\nsquared_error = 58.721\nsamples = 41\nvalue = 180.244'),
#  Text(0.31216216216216214, 0.6071428571428571, 'math score <= 0.625\nsquared_error = 25.139\nsamples = 30\nvalue = 177.167'),
#  Text(0.30154440154440154, 0.5357142857142857, 'reading score <= 0.467\nsquared_error = 14.421\nsamples = 19\nvalue = 175.0'),
#  Text(0.2918918918918919, 0.4642857142857143, 'reading score <= 0.368\nsquared_error = 10.0\nsamples = 12\nvalue = 173.0'),
#  Text(0.29034749034749036, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 164.0'),
#  Text(0.29343629343629346, 0.39285714285714285, 'writing score <= 0.476\nsquared_error = 2.876\nsamples = 11\nvalue = 173.818'),
#  Text(0.28957528957528955, 0.32142857142857145, 'parental level of education <= 0.7\nsquared_error = 0.5\nsamples = 4\nvalue = 172.0'),
#  Text(0.28803088803088805, 0.25, 'lunch <= 0.5\nsquared_error = 0.222\nsamples = 3\nvalue = 171.667'),
#  Text(0.2864864864864865, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 172.0'),
#  Text(0.28957528957528955, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 171.0'),
#  Text(0.2911196911196911, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.2972972972972973, 0.32142857142857145, 'test preparation course <= 0.5\nsquared_error = 1.265\nsamples = 7\nvalue = 174.857'),
#  Text(0.2942084942084942, 0.25, 'writing score <= 0.488\nsquared_error = 0.25\nsamples = 2\nvalue = 173.5'),
#  Text(0.29266409266409266, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.29575289575289576, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 174.0'),
#  Text(0.30038610038610036, 0.25, 'race/ethnicity <= 0.625\nsquared_error = 0.64\nsamples = 5\nvalue = 175.4'),
#  Text(0.29884169884169887, 0.17857142857142858, 'writing score <= 0.488\nsquared_error = 0.667\nsamples = 3\nvalue = 175.0'),
#  Text(0.2972972972972973, 0.10714285714285714, 'parental level of education <= 0.5\nsquared_error = 0.25\nsamples = 2\nvalue = 174.5'),
#  Text(0.29575289575289576, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(0.29884169884169887, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 174.0'),
#  Text(0.30038610038610036, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 176.0'),
#  Text(0.3019305019305019, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 176.0'),
#  Text(0.3111969111969112, 0.4642857142857143, 'math score <= 0.603\nsquared_error = 3.388\nsamples = 7\nvalue = 178.429'),
#  Text(0.3096525096525097, 0.39285714285714285, 'writing score <= 0.518\nsquared_error = 1.472\nsamples = 6\nvalue = 177.833'),
#  Text(0.3081081081081081, 0.32142857142857145, 'reading score <= 0.48\nsquared_error = 0.64\nsamples = 5\nvalue = 177.4'),
#  Text(0.3065637065637066, 0.25, 'race/ethnicity <= 0.25\nsquared_error = 0.667\nsamples = 3\nvalue = 177.0'),
#  Text(0.305019305019305, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.3081081081081081, 0.17857142857142858, 'math score <= 0.565\nsquared_error = 0.25\nsamples = 2\nvalue = 176.5'),
#  Text(0.3065637065637066, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(0.3096525096525097, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 176.0'),
#  Text(0.3096525096525097, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 178.0'),
#  Text(0.3111969111969112, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 180.0'),
#  Text(0.3127413127413127, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.3227799227799228, 0.5357142857142857, 'reading score <= 0.408\nsquared_error = 21.537\nsamples = 11\nvalue = 180.909'),
#  Text(0.3173745173745174, 0.4642857142857143, 'writing score <= 0.453\nsquared_error = 6.222\nsamples = 3\nvalue = 175.333'),
#  Text(0.31583011583011583, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.31891891891891894, 0.39285714285714285, 'race/ethnicity <= 0.625\nsquared_error = 1.0\nsamples = 2\nvalue = 177.0'),
#  Text(0.3173745173745174, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.3204633204633205, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 176.0'),
#  Text(0.3281853281853282, 0.4642857142857143, 'writing score <= 0.471\nsquared_error = 11.25\nsamples = 8\nvalue = 183.0'),
#  Text(0.3250965250965251, 0.39285714285714285, 'math score <= 0.641\nsquared_error = 2.889\nsamples = 3\nvalue = 179.333'),
#  Text(0.32355212355212354, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(0.32664092664092664, 0.32142857142857145, 'reading score <= 0.461\nsquared_error = 0.25\nsamples = 2\nvalue = 180.5'),
#  Text(0.3250965250965251, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 180.0'),
#  Text(0.3281853281853282, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 181.0'),
#  Text(0.3312741312741313, 0.39285714285714285, 'math score <= 0.647\nsquared_error = 3.36\nsamples = 5\nvalue = 185.2'),
#  Text(0.32972972972972975, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 183.0'),
#  Text(0.3328185328185328, 0.32142857142857145, 'math score <= 0.701\nsquared_error = 0.222\nsamples = 3\nvalue = 186.667'),
#  Text(0.3312741312741313, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 187.0'),
#  Text(0.33436293436293435, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 186.0'),
#  Text(0.33976833976833976, 0.6071428571428571, 'math score <= 0.609\nsquared_error = 54.05\nsamples = 11\nvalue = 188.636'),
#  Text(0.33436293436293435, 0.5357142857142857, 'reading score <= 0.467\nsquared_error = 3.04\nsamples = 5\nvalue = 182.4'),
#  Text(0.3328185328185328, 0.4642857142857143, 'squared_error = 0.0\nsamples = 3\nvalue = 181.0'),
#  Text(0.3359073359073359, 0.4642857142857143, 'writing score <= 0.547\nsquared_error = 0.25\nsamples = 2\nvalue = 184.5'),
#  Text(0.33436293436293435, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.33745173745173745, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 184.0'),
#  Text(0.34517374517374516, 0.5357142857142857, 'writing score <= 0.576\nsquared_error = 37.139\nsamples = 6\nvalue = 193.833'),
#  Text(0.3420849420849421, 0.4642857142857143, 'reading score <= 0.414\nsquared_error = 16.25\nsamples = 4\nvalue = 190.5'),
#  Text(0.34054054054054056, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 184.0'),
#  Text(0.3436293436293436, 0.39285714285714285, 'race/ethnicity <= 0.375\nsquared_error = 2.889\nsamples = 3\nvalue = 192.667'),
#  Text(0.3420849420849421, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 195.0'),
#  Text(0.34517374517374516, 0.32142857142857145, 'test preparation course <= 0.5\nsquared_error = 0.25\nsamples = 2\nvalue = 191.5'),
#  Text(0.3436293436293436, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 192.0'),
#  Text(0.3467181467181467, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(0.34826254826254827, 0.4642857142857143, 'gender <= 0.5\nsquared_error = 12.25\nsamples = 2\nvalue = 200.5'),
#  Text(0.3467181467181467, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 197.0'),
#  Text(0.3498069498069498, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 204.0'),
#  Text(0.4096042471042471, 0.6785714285714286, 'math score <= 0.647\nsquared_error = 69.26\nsamples = 71\nvalue = 197.437'),
#  Text(0.37606177606177604, 0.6071428571428571, 'writing score <= 0.582\nsquared_error = 28.57\nsamples = 37\nvalue = 191.568'),
#  Text(0.36486486486486486, 0.5357142857142857, 'math score <= 0.592\nsquared_error = 11.934\nsamples = 19\nvalue = 187.474'),
#  Text(0.3583011583011583, 0.4642857142857143, 'reading score <= 0.539\nsquared_error = 5.537\nsamples = 11\nvalue = 185.091'),
#  Text(0.3544401544401544, 0.39285714285714285, 'gender <= 0.5\nsquared_error = 4.938\nsamples = 8\nvalue = 184.25'),
#  Text(0.35135135135135137, 0.32142857142857145, 'writing score <= 0.571\nsquared_error = 0.688\nsamples = 4\nvalue = 186.25'),
#  Text(0.3498069498069498, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 187.0'),
#  Text(0.3528957528957529, 0.25, 'parental level of education <= 0.9\nsquared_error = 0.25\nsamples = 2\nvalue = 185.5'),
#  Text(0.35135135135135137, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.3544401544401544, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 186.0'),
#  Text(0.3575289575289575, 0.32142857142857145, 'race/ethnicity <= 0.125\nsquared_error = 1.188\nsamples = 4\nvalue = 182.25'),
#  Text(0.355984555984556, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 184.0'),
#  Text(0.3590733590733591, 0.25, 'reading score <= 0.513\nsquared_error = 0.222\nsamples = 3\nvalue = 181.667'),
#  Text(0.3575289575289575, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 182.0'),
#  Text(0.36061776061776063, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 181.0'),
#  Text(0.3621621621621622, 0.39285714285714285, 'lunch <= 0.5\nsquared_error = 0.222\nsamples = 3\nvalue = 187.333'),
#  Text(0.36061776061776063, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 188.0'),
#  Text(0.3637065637065637, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 187.0'),
#  Text(0.37142857142857144, 0.4642857142857143, 'writing score <= 0.547\nsquared_error = 2.188\nsamples = 8\nvalue = 190.75'),
#  Text(0.36833976833976834, 0.39285714285714285, 'parental level of education <= 0.2\nsquared_error = 0.96\nsamples = 5\nvalue = 189.8'),
#  Text(0.3667953667953668, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 189.0'),
#  Text(0.3698841698841699, 0.32142857142857145, 'math score <= 0.614\nsquared_error = 0.889\nsamples = 3\nvalue = 190.333'),
#  Text(0.36833976833976834, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 189.0'),
#  Text(0.37142857142857144, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 191.0'),
#  Text(0.3745173745173745, 0.39285714285714285, 'math score <= 0.625\nsquared_error = 0.222\nsamples = 3\nvalue = 192.333'),
#  Text(0.372972972972973, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 193.0'),
#  Text(0.37606177606177604, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 192.0'),
#  Text(0.3872586872586873, 0.5357142857142857, 'math score <= 0.56\nsquared_error = 9.765\nsamples = 18\nvalue = 195.889'),
#  Text(0.38571428571428573, 0.4642857142857143, 'squared_error = 0.0\nsamples = 2\nvalue = 190.0'),
#  Text(0.3888030888030888, 0.4642857142857143, 'writing score <= 0.629\nsquared_error = 6.109\nsamples = 16\nvalue = 196.625'),
#  Text(0.38223938223938225, 0.39285714285714285, 'reading score <= 0.539\nsquared_error = 2.889\nsamples = 9\nvalue = 195.0'),
#  Text(0.37915057915057915, 0.32142857142857145, 'writing score <= 0.606\nsquared_error = 0.667\nsamples = 3\nvalue = 193.0'),
#  Text(0.3776061776061776, 0.25, 'reading score <= 0.52\nsquared_error = 0.25\nsamples = 2\nvalue = 192.5'),
#  Text(0.37606177606177604, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 193.0'),
#  Text(0.37915057915057915, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 192.0'),
#  Text(0.3806949806949807, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 194.0'),
#  Text(0.3853281853281853, 0.32142857142857145, 'math score <= 0.582\nsquared_error = 1.0\nsamples = 6\nvalue = 196.0'),
#  Text(0.3837837837837838, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 194.0'),
#  Text(0.38687258687258685, 0.25, 'test preparation course <= 0.5\nsquared_error = 0.24\nsamples = 5\nvalue = 196.4'),
#  Text(0.3853281853281853, 0.17857142857142858, 'writing score <= 0.618\nsquared_error = 0.222\nsamples = 3\nvalue = 196.667'),
#  Text(0.3837837837837838, 0.10714285714285714, 'squared_error = 0.0\nsamples = 2\nvalue = 197.0'),
#  Text(0.38687258687258685, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 196.0'),
#  Text(0.3884169884169884, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 196.0'),
#  Text(0.39536679536679536, 0.39285714285714285, 'math score <= 0.592\nsquared_error = 2.49\nsamples = 7\nvalue = 198.714'),
#  Text(0.3915057915057915, 0.32142857142857145, 'test preparation course <= 0.5\nsquared_error = 0.889\nsamples = 3\nvalue = 197.333'),
#  Text(0.38996138996138996, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 198.0'),
#  Text(0.39305019305019306, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 196.0'),
#  Text(0.3992277992277992, 0.32142857142857145, 'race/ethnicity <= 0.625\nsquared_error = 1.188\nsamples = 4\nvalue = 199.75'),
#  Text(0.3961389961389961, 0.25, 'reading score <= 0.546\nsquared_error = 1.0\nsamples = 2\nvalue = 199.0'),
#  Text(0.3945945945945946, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 198.0'),
#  Text(0.39768339768339767, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.4023166023166023, 0.25, 'parental level of education <= 0.4\nsquared_error = 0.25\nsamples = 2\nvalue = 200.5'),
#  Text(0.40077220077220077, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.4038610038610039, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 201.0'),
#  Text(0.44314671814671813, 0.6071428571428571, 'writing score <= 0.606\nsquared_error = 35.263\nsamples = 34\nvalue = 203.824'),
#  Text(0.42644787644787646, 0.5357142857142857, 'math score <= 0.728\nsquared_error = 19.324\nsamples = 21\nvalue = 201.095'),
#  Text(0.4166023166023166, 0.4642857142857143, 'writing score <= 0.553\nsquared_error = 13.209\nsamples = 14\nvalue = 199.071'),
#  Text(0.41003861003861003, 0.39285714285714285, 'test preparation course <= 0.5\nsquared_error = 3.265\nsamples = 7\nvalue = 196.143'),
#  Text(0.4069498069498069, 0.32142857142857145, 'reading score <= 0.546\nsquared_error = 0.25\nsamples = 2\nvalue = 198.5'),
# ...
#  Text(0.8162162162162162, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 240.0'),
#  Text(0.8193050193050193, 0.32142857142857145, 'reading score <= 0.763\nsquared_error = 0.25\nsamples = 2\nvalue = 237.5'),
#  Text(0.8177606177606178, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 238.0'),
#  Text(0.8208494208494208, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 237.0'),
#  Text(0.8223938223938224, 0.4642857142857143, 'reading score <= 0.803\nsquared_error = 8.889\nsamples = 6\nvalue = 247.667'),
#  Text(0.8208494208494208, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.8239382239382239, 0.39285714285714285, 'race/ethnicity <= 0.375\nsquared_error = 2.96\nsamples = 5\nvalue = 248.8'),
#  Text(0.8223938223938224, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 252.0'),
#  Text(0.8254826254826255, 0.32142857142857145, 'reading score <= 0.829\nsquared_error = 0.5\nsamples = 4\nvalue = 248.0'),
#  Text(0.8239382239382239, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 249.0'),
#  Text(0.827027027027027, 0.25, 'writing score <= 0.841\nsquared_error = 0.222\nsamples = 3\nvalue = 247.667'),
#  Text(0.8254826254826255, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 248.0'),
#  Text(0.8285714285714286, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 247.0'),
#  Text(0.875, 0.6785714285714286, 'reading score <= 0.796\nsquared_error = 84.697\nsamples = 64\nvalue = 253.078'),
#  Text(0.8543436293436294, 0.6071428571428571, 'math score <= 0.853\nsquared_error = 27.864\nsamples = 26\nvalue = 245.538'),
#  Text(0.843050193050193, 0.5357142857142857, 'writing score <= 0.759\nsquared_error = 10.975\nsamples = 19\nvalue = 243.158'),
#  Text(0.8362934362934363, 0.4642857142857143, 'parental level of education <= 0.5\nsquared_error = 4.889\nsamples = 6\nvalue = 240.333'),
#  Text(0.8347490347490347, 0.39285714285714285, 'math score <= 0.799\nsquared_error = 3.25\nsamples = 4\nvalue = 241.5'),
#  Text(0.8316602316602316, 0.32142857142857145, 'race/ethnicity <= 0.875\nsquared_error = 1.0\nsamples = 2\nvalue = 240.0'),
#  Text(0.8301158301158301, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 239.0'),
#  Text(0.8332046332046332, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 241.0'),
#  Text(0.8378378378378378, 0.32142857142857145, 'parental level of education <= 0.2\nsquared_error = 1.0\nsamples = 2\nvalue = 243.0'),
#  Text(0.8362934362934363, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 244.0'),
#  Text(0.8393822393822394, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.8378378378378378, 0.39285714285714285, 'squared_error = 0.0\nsamples = 2\nvalue = 238.0'),
#  Text(0.8498069498069498, 0.4642857142857143, 'math score <= 0.777\nsquared_error = 8.402\nsamples = 13\nvalue = 244.462'),
#  Text(0.8455598455598455, 0.39285714285714285, 'parental level of education <= 0.7\nsquared_error = 3.84\nsamples = 5\nvalue = 241.6'),
#  Text(0.844015444015444, 0.32142857142857145, 'parental level of education <= 0.3\nsquared_error = 1.188\nsamples = 4\nvalue = 240.75'),
#  Text(0.8424710424710424, 0.25, 'race/ethnicity <= 0.875\nsquared_error = 0.222\nsamples = 3\nvalue = 241.333'),
#  Text(0.8409266409266409, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 241.0'),
#  Text(0.844015444015444, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.8455598455598455, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 239.0'),
#  Text(0.8471042471042471, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 245.0'),
#  Text(0.8540540540540541, 0.39285714285714285, 'race/ethnicity <= 0.375\nsquared_error = 2.938\nsamples = 8\nvalue = 246.25'),
#  Text(0.8501930501930502, 0.32142857142857145, 'writing score <= 0.776\nsquared_error = 0.222\nsamples = 3\nvalue = 244.333'),
#  Text(0.8486486486486486, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 244.0'),
#  Text(0.8517374517374517, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 245.0'),
#  Text(0.857915057915058, 0.32142857142857145, 'math score <= 0.804\nsquared_error = 1.04\nsamples = 5\nvalue = 247.4'),
#  Text(0.8548262548262548, 0.25, 'math score <= 0.788\nsquared_error = 0.25\nsamples = 2\nvalue = 246.5'),
#  Text(0.8532818532818532, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(0.8563706563706563, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 247.0'),
#  Text(0.861003861003861, 0.25, 'parental level of education <= 0.3\nsquared_error = 0.667\nsamples = 3\nvalue = 248.0'),
#  Text(0.8594594594594595, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 249.0'),
#  Text(0.8625482625482626, 0.17857142857142858, 'reading score <= 0.77\nsquared_error = 0.25\nsamples = 2\nvalue = 247.5'),
#  Text(0.861003861003861, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 247.0'),
#  Text(0.864092664092664, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 248.0'),
#  Text(0.8656370656370657, 0.5357142857142857, 'writing score <= 0.771\nsquared_error = 16.571\nsamples = 7\nvalue = 252.0'),
#  Text(0.861003861003861, 0.4642857142857143, 'math score <= 0.875\nsquared_error = 3.188\nsamples = 4\nvalue = 248.75'),
#  Text(0.8594594594594595, 0.39285714285714285, 'squared_error = 0.0\nsamples = 2\nvalue = 247.0'),
#  Text(0.8625482625482626, 0.39285714285714285, 'math score <= 0.891\nsquared_error = 0.25\nsamples = 2\nvalue = 250.5'),
#  Text(0.861003861003861, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 250.0'),
#  Text(0.864092664092664, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 251.0'),
#  Text(0.8702702702702703, 0.4642857142857143, 'writing score <= 0.835\nsquared_error = 1.556\nsamples = 3\nvalue = 256.333'),
#  Text(0.8687258687258688, 0.39285714285714285, 'parental level of education <= 0.3\nsquared_error = 0.25\nsamples = 2\nvalue = 255.5'),
#  Text(0.8671814671814672, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 256.0'),
#  Text(0.8702702702702703, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 255.0'),
#  Text(0.8718146718146718, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(0.8956563706563706, 0.6071428571428571, 'math score <= 0.832\nsquared_error = 58.075\nsamples = 38\nvalue = 258.237'),
#  Text(0.8861003861003861, 0.5357142857142857, 'reading score <= 0.875\nsquared_error = 16.44\nsamples = 20\nvalue = 253.4'),
#  Text(0.8803088803088803, 0.4642857142857143, 'writing score <= 0.853\nsquared_error = 8.756\nsamples = 15\nvalue = 251.667'),
#  Text(0.8787644787644787, 0.39285714285714285, 'math score <= 0.788\nsquared_error = 5.053\nsamples = 13\nvalue = 250.846'),
#  Text(0.8733590733590734, 0.32142857142857145, 'writing score <= 0.782\nsquared_error = 3.284\nsamples = 9\nvalue = 249.778'),
#  Text(0.8718146718146718, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(0.8749034749034749, 0.25, 'reading score <= 0.836\nsquared_error = 1.688\nsamples = 8\nvalue = 250.25'),
#  Text(0.8718146718146718, 0.17857142857142858, 'math score <= 0.761\nsquared_error = 0.688\nsamples = 4\nvalue = 249.25'),
#  Text(0.8702702702702703, 0.10714285714285714, 'math score <= 0.745\nsquared_error = 0.25\nsamples = 2\nvalue = 248.5'),
#  Text(0.8687258687258688, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 248.0'),
#  Text(0.8718146718146718, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 249.0'),
#  Text(0.8733590733590734, 0.10714285714285714, 'squared_error = 0.0\nsamples = 2\nvalue = 250.0'),
#  Text(0.877992277992278, 0.17857142857142858, 'race/ethnicity <= 0.375\nsquared_error = 0.688\nsamples = 4\nvalue = 251.25'),
#  Text(0.8764478764478765, 0.10714285714285714, 'test preparation course <= 0.5\nsquared_error = 0.25\nsamples = 2\nvalue = 250.5'),
#  Text(0.8749034749034749, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 250.0'),
#  Text(0.877992277992278, 0.03571428571428571, 'squared_error = 0.0\nsamples = 1\nvalue = 251.0'),
#  Text(0.8795366795366796, 0.10714285714285714, 'squared_error = 0.0\nsamples = 2\nvalue = 252.0'),
#  Text(0.8841698841698842, 0.32142857142857145, 'writing score <= 0.841\nsquared_error = 0.688\nsamples = 4\nvalue = 253.25'),
#  Text(0.8826254826254826, 0.25, 'math score <= 0.815\nsquared_error = 0.25\nsamples = 2\nvalue = 252.5'),
#  Text(0.8810810810810811, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 253.0'),
#  Text(0.8841698841698842, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 252.0'),
#  Text(0.8857142857142857, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 254.0'),
#  Text(0.8818532818532818, 0.39285714285714285, 'squared_error = 0.0\nsamples = 2\nvalue = 257.0'),
#  Text(0.8918918918918919, 0.4642857142857143, 'math score <= 0.766\nsquared_error = 3.44\nsamples = 5\nvalue = 258.6'),
#  Text(0.8888030888030888, 0.39285714285714285, 'math score <= 0.745\nsquared_error = 0.25\nsamples = 2\nvalue = 256.5'),
#  Text(0.8872586872586873, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 257.0'),
#  Text(0.8903474903474904, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 256.0'),
#  Text(0.894980694980695, 0.39285714285714285, 'parental level of education <= 0.5\nsquared_error = 0.667\nsamples = 3\nvalue = 260.0'),
#  Text(0.8934362934362934, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 261.0'),
#  Text(0.8965250965250965, 0.32142857142857145, 'race/ethnicity <= 0.625\nsquared_error = 0.25\nsamples = 2\nvalue = 259.5'),
#  Text(0.894980694980695, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 259.0'),
#  Text(0.8980694980694981, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 260.0'),
#  Text(0.9052123552123552, 0.5357142857142857, 'race/ethnicity <= 0.125\nsquared_error = 49.46\nsamples = 18\nvalue = 263.611'),
#  Text(0.8996138996138996, 0.4642857142857143, 'reading score <= 0.921\nsquared_error = 12.25\nsamples = 2\nvalue = 278.5'),
#  Text(0.8980694980694981, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 275.0'),
#  Text(0.9011583011583012, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 282.0'),
#  Text(0.9108108108108108, 0.4642857142857143, 'writing score <= 0.765\nsquared_error = 22.938\nsamples = 16\nvalue = 261.75'),
#  Text(0.9042471042471042, 0.39285714285714285, 'test preparation course <= 0.5\nsquared_error = 11.556\nsamples = 3\nvalue = 253.667'),
#  Text(0.9027027027027027, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 249.0'),
#  Text(0.9057915057915058, 0.32142857142857145, 'math score <= 0.897\nsquared_error = 1.0\nsamples = 2\nvalue = 256.0'),
#  Text(0.9042471042471042, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 255.0'),
#  Text(0.9073359073359073, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 257.0'),
#  Text(0.9173745173745174, 0.39285714285714285, 'writing score <= 0.829\nsquared_error = 7.006\nsamples = 13\nvalue = 263.615'),
#  Text(0.911969111969112, 0.32142857142857145, 'parental level of education <= 0.7\nsquared_error = 5.143\nsamples = 7\nvalue = 262.0'),
#  Text(0.9104247104247104, 0.25, 'writing score <= 0.782\nsquared_error = 1.139\nsamples = 6\nvalue = 261.167'),
#  Text(0.9088803088803089, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 259.0'),
#  Text(0.911969111969112, 0.17857142857142858, 'reading score <= 0.816\nsquared_error = 0.24\nsamples = 5\nvalue = 261.6'),
#  Text(0.9104247104247104, 0.10714285714285714, 'squared_error = 0.0\nsamples = 2\nvalue = 261.0'),
#  Text(0.9135135135135135, 0.10714285714285714, 'squared_error = 0.0\nsamples = 3\nvalue = 262.0'),
#  Text(0.9135135135135135, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 267.0'),
#  Text(0.9227799227799228, 0.32142857142857145, 'race/ethnicity <= 0.375\nsquared_error = 2.583\nsamples = 6\nvalue = 265.5'),
#  Text(0.9196911196911197, 0.25, 'writing score <= 0.853\nsquared_error = 1.556\nsamples = 3\nvalue = 266.667'),
#  Text(0.9181467181467181, 0.17857142857142858, 'test preparation course <= 0.5\nsquared_error = 0.25\nsamples = 2\nvalue = 267.5'),
#  Text(0.9166023166023166, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 267.0'),
#  Text(0.9196911196911197, 0.10714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 268.0'),
#  Text(0.9212355212355212, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 265.0'),
#  Text(0.9258687258687258, 0.25, 'parental level of education <= 0.3\nsquared_error = 0.889\nsamples = 3\nvalue = 264.333'),
#  Text(0.9243243243243243, 0.17857142857142858, 'squared_error = 0.0\nsamples = 2\nvalue = 265.0'),
#  Text(0.9274131274131274, 0.17857142857142858, 'squared_error = 0.0\nsamples = 1\nvalue = 263.0'),
#  Text(0.9561776061776062, 0.75, 'math score <= 0.864\nsquared_error = 170.34\nsamples = 50\nvalue = 277.02'),
#  Text(0.9345559845559845, 0.6785714285714286, 'reading score <= 0.849\nsquared_error = 53.969\nsamples = 22\nvalue = 265.591'),
#  Text(0.9243243243243243, 0.6071428571428571, 'reading score <= 0.796\nsquared_error = 22.188\nsamples = 8\nvalue = 258.25'),
#  Text(0.9212355212355212, 0.5357142857142857, 'math score <= 0.761\nsquared_error = 6.222\nsamples = 3\nvalue = 253.333'),
#  Text(0.9196911196911197, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 250.0'),
#  Text(0.9227799227799228, 0.4642857142857143, 'test preparation course <= 0.5\nsquared_error = 1.0\nsamples = 2\nvalue = 255.0'),
#  Text(0.9212355212355212, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 254.0'),
#  Text(0.9243243243243243, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 256.0'),
#  Text(0.9274131274131274, 0.5357142857142857, 'race/ethnicity <= 0.25\nsquared_error = 8.56\nsamples = 5\nvalue = 261.2'),
#  Text(0.9258687258687258, 0.4642857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 256.0'),
#  Text(0.9289575289575289, 0.4642857142857143, 'math score <= 0.853\nsquared_error = 2.25\nsamples = 4\nvalue = 262.5'),
#  Text(0.9274131274131274, 0.39285714285714285, 'parental level of education <= 0.4\nsquared_error = 0.222\nsamples = 3\nvalue = 261.667'),
#  Text(0.9258687258687258, 0.32142857142857145, 'squared_error = 0.0\nsamples = 1\nvalue = 261.0'),
#  Text(0.9289575289575289, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 262.0'),
#  Text(0.9305019305019305, 0.39285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 265.0'),
#  Text(0.9447876447876448, 0.6071428571428571, 'reading score <= 0.98\nsquared_error = 23.74\nsamples = 14\nvalue = 269.786'),
#  Text(0.9432432432432433, 0.5357142857142857, 'writing score <= 0.947\nsquared_error = 13.207\nsamples = 13\nvalue = 268.846'),
#  Text(0.938996138996139, 0.4642857142857143, 'math score <= 0.81\nsquared_error = 8.694\nsamples = 11\nvalue = 267.818'),
#  Text(0.9351351351351351, 0.39285714285714285, 'race/ethnicity <= 0.625\nsquared_error = 6.806\nsamples = 6\nvalue = 265.833'),
#  Text(0.932046332046332, 0.32142857142857145, 'reading score <= 0.888\nsquared_error = 0.75\nsamples = 4\nvalue = 267.5'),
#  Text(0.9305019305019305, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 266.0'),
#  Text(0.9335907335907336, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 268.0'),
#  Text(0.9382239382239382, 0.32142857142857145, 'parental level of education <= 0.4\nsquared_error = 2.25\nsamples = 2\nvalue = 262.5'),
#  Text(0.9366795366795366, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 261.0'),
#  Text(0.9397683397683397, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 264.0'),
#  Text(0.9428571428571428, 0.39285714285714285, 'math score <= 0.832\nsquared_error = 0.56\nsamples = 5\nvalue = 270.2'),
#  Text(0.9413127413127413, 0.32142857142857145, 'squared_error = 0.0\nsamples = 2\nvalue = 271.0'),
#  Text(0.9444015444015444, 0.32142857142857145, 'test preparation course <= 0.5\nsquared_error = 0.222\nsamples = 3\nvalue = 269.667'),
#  Text(0.9428571428571428, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 270.0'),
#  Text(0.9459459459459459, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 269.0'),
#  ...]

# %%
## hyperparameter tuning
from sklearn.model_selection import GridSearchCV
param_grid = { "ccp_alpha": [0.1, 1, 10, 100],
                    "min_samples_split": [2, 5, 10], 
                            "min_samples_leaf": [1, 2, 4],
                            "max_depth": [None, 10, 20, 30]}
for i in param_grid:
    print(i, ":", param_grid[i])
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
    grid_search.fit(x_train, y_train)
    print("Best parameters: ", grid_search.best_params_)
    best_model = grid_search.best_estimator_
    y_pred_train = best_model.predict(x_train)
    y_pred_test = best_model.predict(x_test)
    print("R2 score for train data: ", r2_score(y_train, y_pred_train))
    print("R2 score for test data: ", r2_score(y_test, y_pred_test))
    print("Mean squared error for train data: ", mean_squared_error(y_train, y_pred_train))
    print("Mean squared error for test data: ", mean_squared_error(y_test, y_pred_test))
# Out:
# ccp_alpha : [0.1, 1, 10, 100]
# Best parameters:  {'ccp_alpha': 0.1, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# R2 score for train data:  0.9966950560952091
# R2 score for test data:  0.9835736558519932
# Mean squared error for train data:  5.897597125097125
# Mean squared error for test data:  29.98638813195074
# min_samples_split : [2, 5, 10]
# Best parameters:  {'ccp_alpha': 0.1, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# R2 score for train data:  0.9966840112910937
# R2 score for test data:  0.986108091100296
# Mean squared error for train data:  5.917306326486014
# Mean squared error for test data:  25.359761636966166
# min_samples_leaf : [1, 2, 4]
# Best parameters:  {'ccp_alpha': 0.1, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# R2 score for train data:  0.9966950560952091
# R2 score for test data:  0.9862534566632024
# Mean squared error for train data:  5.897597125097125
# Mean squared error for test data:  25.09439594445074
# max_depth : [None, 10, 20, 30]
# Best parameters:  {'ccp_alpha': 0.1, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# R2 score for train data:  0.9959584288742008
# R2 score for test data:  0.984581345501305
# Mean squared error for train data:  7.212091623654123
# Mean squared error for test data:  28.146844733337456

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
param_dist = { "ccp_alpha" : randint(0, 100),
                "min_samples_split" : randint(2, 10),
                "min_samples_leaf" : randint(1, 4),
                "max_depth" : [None, 10, 20, 30]}
dtree = DecisionTreeRegressor()
random_search = RandomizedSearchCV(estimator=dtree, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)
print("Best parameters: ", random_search.best_params_)
best_model = random_search.best_estimator_
y_pred_train = best_model.predict(x_train)  
y_pred_test = best_model.predict(x_test)
print("R2 score for train data: ", r2_score(y_train, y_pred_train))
print("R2 score for test data: ", r2_score(y_test, y_pred_test))
print("Mean squared error for train data: ", mean_squared_error(y_train, y_pred_train))
print("Mean squared error for test data: ", mean_squared_error(y_test, y_pred_test))
# Out:
# Best parameters:  {'ccp_alpha': 1, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# R2 score for train data:  0.9856458687452252
# R2 score for test data:  0.9746251092658131
# Mean squared error for train data:  25.614620296190417
# Mean squared error for test data:  46.32201270746523

# %%
# Best parameters:  {'ccp_alpha': 0.1, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
dtree_final = DecisionTreeRegressor(ccp_alpha=0.1, max_depth=30, min_samples_leaf=1, min_samples_split=2)
dtree_final.fit(x_train, y_train)
y_pred_train = dtree_final.predict(x_train)
y_pred_final = dtree_final.predict(x_test)
print("R2 score for train data: ", r2_score(y_train, y_pred_train))
print("R2 score for test data: ", r2_score(y_test, y_pred_final))
print("Mean squared error for train data: ", mean_squared_error(y_train, y_pred_train))
print("Mean squared error for test data: ", mean_squared_error(y_test, y_pred_final))
# Out:
# R2 score for train data:  0.9966950560952091
# R2 score for test data:  0.9846100765993155
# Mean squared error for train data:  5.897597125097125
# Mean squared error for test data:  28.094395944450742
